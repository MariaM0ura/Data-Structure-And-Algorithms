# %% [markdown]
# #Lista Encadeada Simples Extremidade Dupla

# %%
class No:
    def __init__(self, valor):
        self.valor = valor
        self.proximo = None

    def mostra_no(self):
        print(self.valor)

# %%
class ListaEncadeadaExtremidadeDupla:
    def __init__(self):
        self.primeiro = None
        self.ultimo = None

    def __lista_vazia(self):
        return  self.primeiro == None

    def insere_inicio(self, valor):
        novo = No(valor)
        if self.__lista_vazia():
            self.ultimo = novo
        novo.proximo = self.primeiro
        self.primeiro = novo

    def mostrar(self):
        if self.__lista_vazia():
            print("A lista esta vazia")
            return
        atual = self.primeiro
        while atual != None:
          atual.mostra_no()
          atual = atual.proximo

    def insere_final(self, valor):
      novo = No(valor)
      if self.__lista_vazia():
          self.primeiro = novo
      else:
          self.ultimo.proximo = novo
      self.ultimo = novo

    def exclui_inicio(self):
        if self.__lista_vazia():
            print("A lista esta vazia")
            return
        temp = self.primeiro
        if self.primeiro.proximo == None:
            self.ultimo = None
        self.primeiro = self.primeiro.proximo
        return temp

# %% [markdown]
# ###Teste Inicio e Mostra

# %%
lista = ListaEncadeadaExtremidadeDupla()

# %%
lista.insere_inicio(1)

# %%
lista.mostrar()
# Out:
# 1

# %%
lista.primeiro, lista.ultimo
# Out:
# (<__main__.No at 0x7980e676a260>, <__main__.No at 0x7980e676a260>)

# %%
lista.insere_inicio(2)

# %%
lista.mostrar()
# Out:
# 2
# 1

# %%
lista.primeiro, lista.ultimo
# Out:
# (<__main__.No at 0x7980e676a770>, <__main__.No at 0x7980e676a260>)

# %% [markdown]
# ###Teste Insere FInal

# %%
lista = ListaEncadeadaExtremidadeDupla()

# %%
lista.insere_final(1)

# %%
lista.mostrar()
# Out:
# 1

# %%
lista.insere_final(2)
lista.mostrar()
# Out:
# 1
# 2

# %%
lista.insere_final(3)
lista.mostrar()
# Out:
# 1
# 2
# 3

# %%
lista.insere_inicio(0)
lista.mostrar()
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ###Teste Exclui Inicio

# %%
lista = ListaEncadeadaExtremidadeDupla()

# %%
lista.insere_inicio(1)
lista.insere_inicio(2)
lista.insere_inicio(3)
lista.mostrar()
# Out:
# 3
# 2
# 1

# %%
lista.exclui_inicio()

# %%
lista.mostrar()
# Out:
# 2
# 1

# %%
lista.exclui_inicio()
lista.exclui_inicio()
lista.exclui_inicio()
# Out:
# A lista esta vazia
